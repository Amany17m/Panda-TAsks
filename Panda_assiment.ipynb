# %%
import pandas as pd

# %%
df_grades=pd.read_csv('Grades_Short.csv')
df_grades.head()
# Out:
#     Name  Previous_Part  Participation1  Mini_Exam1  Mini_Exam2  \
# 0   Jake           32.0               1        19.5          20
# 1    Joe           32.0               1        20.0          16
# 2  Susan           30.0               1        19.0          19
# 3    Sol           31.0               1        22.0          13
# 4  Chris           30.0               1        19.0          17
#
#    Participation2  Mini_Exam3  Final Grade     ID
# 0               1        10.0   33.0     A  90743
# 1               1        14.0   32.0     A   7284
# 2               1        10.5   33.0    A-   7625
# 3               1        13.0   34.0     A   1237
# 4               1        12.5   33.5     A     62

# %%
df_grades.head(3)
# Out:
#     Name  Previous_Part  Participation1  Mini_Exam1  Mini_Exam2  \
# 0   Jake           32.0               1        19.5          20
# 1    Joe           32.0               1        20.0          16
# 2  Susan           30.0               1        19.0          19
#
#    Participation2  Mini_Exam3  Final Grade     ID
# 0               1        10.0   33.0     A  90743
# 1               1        14.0   32.0     A   7284
# 2               1        10.5   33.0    A-   7625

# %%
df_grades.shape
# Out:
# (7, 10)

# %%
df_grades.dtypes
# Out:
# Name               object
# Previous_Part     float64
# Participation1      int64
# Mini_Exam1        float64
# Mini_Exam2          int64
# Participation2      int64
# Mini_Exam3        float64
# Final             float64
# Grade              object
# ID                  int64
# dtype: object

# %%
#getting Columns Names
df_grades.columns
# Out:
# Index(['Name', 'Previous_Part', 'Participation1', 'Mini_Exam1', 'Mini_Exam2',
#        'Participation2', 'Mini_Exam3', 'Final', 'Grade', 'ID'],
#       dtype='object')

# %%
#getting rows Names
df_grades.index
# Out:
# RangeIndex(start=0, stop=7, step=1)

# %%
#getting a single Column
df_grades['Name']
# Out:
# 0     Jake
# 1      Joe
# 2    Susan
# 3      Sol
# 4    Chris
# 5    Tarik
# 6    Malik
# Name: Name, dtype: object

# %%
df_grades.Name
# Out:
# 0     Jake
# 1      Joe
# 2    Susan
# 3      Sol
# 4    Chris
# 5    Tarik
# 6    Malik
# Name: Name, dtype: object

# %%
#getting two columns
df_grades[['Name','Grade']]
# Out:
#     Name Grade
# 0   Jake     A
# 1    Joe     A
# 2  Susan    A-
# 3    Sol     A
# 4  Chris     A
# 5  Tarik     B
# 6  Malik     A

# %%
#storing results 
names=df_grades['Name']
names
# Out:
# 0     Jake
# 1      Joe
# 2    Susan
# 3      Sol
# 4    Chris
# 5    Tarik
# 6    Malik
# Name: Name, dtype: object

# %%
names[0]
# Out:
# 'Jake'

# %%
names[1:5]
# Out:
# 1      Joe
# 2    Susan
# 3      Sol
# 4    Chris
# Name: Name, dtype: object

# %%
#pay attention to the duble [[
names[[1,2,4]]
# Out:
# 1      Joe
# 2    Susan
# 4    Chris
# Name: Name, dtype: object

# %%
First_Name=df_grades.loc[0,'Name']
First_Name
# Out:
# 'Jake'

# %%
First_Row=df_grades.loc[0,:]
First_Row
# Out:
# Name               Jake
# Previous_Part      32.0
# Participation1        1
# Mini_Exam1         19.5
# Mini_Exam2           20
# Participation2        1
# Mini_Exam3         10.0
# Final              33.0
# Grade                 A
# ID                90743
# Name: 0, dtype: object

# %%
Silce_one=df_grades.loc[0:2,'Name':'Mini_Exam2']
Silce_one
# Out:
#     Name  Previous_Part  Participation1  Mini_Exam1  Mini_Exam2
# 0   Jake           32.0               1        19.5          20
# 1    Joe           32.0               1        20.0          16
# 2  Susan           30.0               1        19.0          19

# %%
silce_two=df_grades.loc[[0,2,3],['Name','Grade']]
silce_two
# Out:
#     Name Grade
# 0   Jake     A
# 2  Susan    A-
# 3    Sol     A

# %%
#pay attention to the upper letter ___ it's F not f
#computing the finnal average
average_degrees=df_grades.Final.mean()
average_degrees
# Out:
# 32.214285714285715

# %%
Max_Min=df_grades.Mini_Exam1.max()
Max_Min
# Out:
# 22.0

# %%
df_grades.describe()
# Out:
#        Previous_Part  Participation1  Mini_Exam1  Mini_Exam2  Participation2  \
# count       7.000000             7.0    7.000000    7.000000             7.0
# mean       31.071429             1.0   19.785714   17.857143             1.0
# std         0.838082             0.0    1.074598    2.734262             0.0
# min        30.000000             1.0   19.000000   13.000000             1.0
# 25%        30.500000             1.0   19.000000   16.500000             1.0
# 50%        31.000000             1.0   19.500000   19.000000             1.0
# 75%        31.750000             1.0   20.000000   19.500000             1.0
# max        32.000000             1.0   22.000000   21.000000             1.0
#
#        Mini_Exam3      Final           ID
# count    7.000000   7.000000      7.00000
# mean    11.000000  32.214286  29111.00000
# std      2.217356   3.828154  41131.08167
# min      8.000000  24.000000     62.00000
# 25%      9.500000  32.500000   4260.50000
# ...

# %%
summary_df=df_grades[['Final','Mini_Exam1']]
summary_df.describe()
# Out:
#            Final  Mini_Exam1
# count   7.000000    7.000000
# mean   32.214286   19.785714
# std     3.828154    1.074598
# min    24.000000   19.000000
# 25%    32.500000   19.000000
# 50%    33.000000   19.500000
# 75%    33.750000   20.000000
# max    36.000000   22.000000

# %%
df_grades['Grade'].value_counts()
# Out:
# Grade
# A     5
# A-    1
# B     1
# Name: count, dtype: int64

# %%
Counts=df_grades['Grade'].value_counts()
Counts['A']
# Out:
# 5

# %%
df_grades['Grade'].unique()
# Out:
# array(['A', 'A-', 'B'], dtype=object)

# %%
Unique=df_grades['Grade'].unique()
Unique[0]
# Out:
# 'A'

# %%
len(Unique)
# Out:
# 3

# %%
df_grades['New_Column']=1
df_grades
# Out:
#     Name  Previous_Part  Participation1  Mini_Exam1  Mini_Exam2  \
# 0   Jake           32.0               1        19.5          20
# 1    Joe           32.0               1        20.0          16
# 2  Susan           30.0               1        19.0          19
# 3    Sol           31.0               1        22.0          13
# 4  Chris           30.0               1        19.0          17
# 5  Tarik           31.0               1        19.0          19
# 6  Malik           31.5               1        20.0          21
#
#    Participation2  Mini_Exam3  Final Grade     ID  New_Column
# 0               1        10.0   33.0     A  90743           1
# 1               1        14.0   32.0     A   7284           1
# 2               1        10.5   33.0    A-   7625           1
# 3               1        13.0   34.0     A   1237           1
# 4               1        12.5   33.5     A     62           1
# 5               1         8.0   24.0     B  87452           1
# ...

# %%
df_grades["Final_Precentage"]= df_grades['Final']/36
df_grades
# Out:
#     Name  Previous_Part  Participation1  Mini_Exam1  Mini_Exam2  \
# 0   Jake           32.0               1        19.5          20
# 1    Joe           32.0               1        20.0          16
# 2  Susan           30.0               1        19.0          19
# 3    Sol           31.0               1        22.0          13
# 4  Chris           30.0               1        19.0          17
# 5  Tarik           31.0               1        19.0          19
# 6  Malik           31.5               1        20.0          21
#
#    Participation2  Mini_Exam3  Final Grade     ID  New_Column  \
# 0               1        10.0   33.0     A  90743           1
# 1               1        14.0   32.0     A   7284           1
# 2               1        10.5   33.0    A-   7625           1
# 3               1        13.0   34.0     A   1237           1
# 4               1        12.5   33.5     A     62           1
# 5               1         8.0   24.0     B  87452           1
# ...

# %%
del df_grades["Final_Precentage"]
df_grades
# Out:
#     Name  Previous_Part  Participation1  Mini_Exam1  Mini_Exam2  \
# 0   Jake           32.0               1        19.5          20
# 1    Joe           32.0               1        20.0          16
# 2  Susan           30.0               1        19.0          19
# 3    Sol           31.0               1        22.0          13
# 4  Chris           30.0               1        19.0          17
# 5  Tarik           31.0               1        19.0          19
# 6  Malik           31.5               1        20.0          21
#
#    Participation2  Mini_Exam3  Final Grade     ID  New_Column
# 0               1        10.0   33.0     A  90743           1
# 1               1        14.0   32.0     A   7284           1
# 2               1        10.5   33.0    A-   7625           1
# 3               1        13.0   34.0     A   1237           1
# 4               1        12.5   33.5     A     62           1
# 5               1         8.0   24.0     B  87452           1
# ...

# %%
df_grades['part_pic']=1.0
df_grades
# Out:
#     Name  Previous_Part  Participation1  Mini_Exam1  Mini_Exam2  \
# 0   Jake           32.0               1        19.5          20
# 1    Joe           32.0               1        20.0          16
# 2  Susan           30.0               1        19.0          19
# 3    Sol           31.0               1        22.0          13
# 4  Chris           30.0               1        19.0          17
# 5  Tarik           31.0               1        19.0          19
# 6  Malik           31.5               1        20.0          21
#
#    Participation2  Mini_Exam3  Final Grade     ID  New_Column  part_pic
# 0               1        10.0   33.0     A  90743           1       1.0
# 1               1        14.0   32.0     A   7284           1       1.0
# 2               1        10.5   33.0    A-   7625           1       1.0
# 3               1        13.0   34.0     A   1237           1       1.0
# 4               1        12.5   33.5     A     62           1       1.0
# ...

# %%
df_grades.drop(['New_Column','part_pic'] ,axis=1 ,inplace=True)
df_grades
# Out:
#     Name  Previous_Part  Participation1  Mini_Exam1  Mini_Exam2  \
# 0   Jake           32.0               1        19.5          20
# 1    Joe           32.0               1        20.0          16
# 2  Susan           30.0               1        19.0          19
# 3    Sol           31.0               1        22.0          13
# 4  Chris           30.0               1        19.0          17
# 5  Tarik           31.0               1        19.0          19
# 6  Malik           31.5               1        20.0          21
#
#    Participation2  Mini_Exam3  Final Grade     ID
# 0               1        10.0   33.0     A  90743
# 1               1        14.0   32.0     A   7284
# 2               1        10.5   33.0    A-   7625
# 3               1        13.0   34.0     A   1237
# 4               1        12.5   33.5     A     62
# 5               1         8.0   24.0     B  87452
# 6               1         9.0   36.0     A   9374

# %%
##########################################

# %%
Missing Values

# %%
df_missing=pd.read_csv('Missing_Data.csv')
df_missing
# Out:
#     Name  Previous_Part  Participation1  Mini_Exam1     Mini_Exam2  \
# 0   Jake           32.0               1        19.5             20
# 1    Joe            NaN               1        20.0             16
# 2    Sol           31.0               1        22.0             13
# 3  Chris           30.0              -1        19.0  not available
#
#    Participation2  Mini_Exam3  Final Grade  Temp
# 0               1        10.0   33.0     A    -1
# 1               1        14.0   32.0     A    23
# 2               1        13.0   34.0     A    34
# 3               1        12.5   33.5     A    72

# %%
df_missing.dtypes
# Out:
# Name               object
# Previous_Part     float64
# Participation1      int64
# Mini_Exam1        float64
# Mini_Exam2         object
# Participation2      int64
# Mini_Exam3        float64
# Final             float64
# Grade              object
# Temp                int64
# dtype: object

# %%
df_missing=pd.read_csv('Missing_Data.csv', na_values=['NaN', 'not_avilable' ])
df_missing
# Out:
#     Name  Previous_Part  Participation1  Mini_Exam1     Mini_Exam2  \
# 0   Jake           32.0               1        19.5             20
# 1    Joe            NaN               1        20.0             16
# 2    Sol           31.0               1        22.0             13
# 3  Chris           30.0              -1        19.0  not available
#
#    Participation2  Mini_Exam3  Final Grade  Temp
# 0               1        10.0   33.0     A    -1
# 1               1        14.0   32.0     A    23
# 2               1        13.0   34.0     A    34
# 3               1        12.5   33.5     A    72

# %%
df_missing=pd.read_csv('Missing_Data.csv', na_values={'Mini_Exam2':'not_available', 'Participation1':-1})
df_missing
# Out:
#     Name  Previous_Part  Participation1  Mini_Exam1     Mini_Exam2  \
# 0   Jake           32.0             1.0        19.5             20
# 1    Joe            NaN             1.0        20.0             16
# 2    Sol           31.0             1.0        22.0             13
# 3  Chris           30.0             NaN        19.0  not available
#
#    Participation2  Mini_Exam3  Final Grade  Temp
# 0               1        10.0   33.0     A    -1
# 1               1        14.0   32.0     A    23
# 2               1        13.0   34.0     A    34
# 3               1        12.5   33.5     A    72

# %%
df_missing.isnull()
# Out:
#     Name  Previous_Part  Participation1  Mini_Exam1  Mini_Exam2  \
# 0  False          False           False       False       False
# 1  False           True           False       False       False
# 2  False          False           False       False       False
# 3  False          False           False       False       False
#
#    Participation2  Mini_Exam3  Final  Grade   Temp
# 0           False       False  False  False  False
# 1           False       False  False  False  False
# 2           False       False  False  False  False
# 3           False       False  False  False  False

# %%
df_missing.isnull().sum()
# Out:
# Name              0
# Previous_Part     1
# Participation1    0
# Mini_Exam1        0
# Mini_Exam2        0
# Participation2    0
# Mini_Exam3        0
# Final             0
# Grade             0
# Temp              0
# dtype: int64

# %%
df_missing.dropna(axis=0, inplace=False)
# Out:
#     Name  Previous_Part  Participation1  Mini_Exam1     Mini_Exam2  \
# 0   Jake           32.0               1        19.5             20
# 2    Sol           31.0               1        22.0             13
# 3  Chris           30.0              -1        19.0  not available
#
#    Participation2  Mini_Exam3  Final Grade  Temp
# 0               1        10.0   33.0     A    -1
# 2               1        13.0   34.0     A    34
# 3               1        12.5   33.5     A    72

# %%
df_missing.fillna(0,inplace=False)
# Out:
#     Name  Previous_Part  Participation1  Mini_Exam1     Mini_Exam2  \
# 0   Jake           32.0               1        19.5             20
# 1    Joe            0.0               1        20.0             16
# 2    Sol           31.0               1        22.0             13
# 3  Chris           30.0              -1        19.0  not available
#
#    Participation2  Mini_Exam3  Final Grade  Temp
# 0               1        10.0   33.0     A    -1
# 1               1        14.0   32.0     A    23
# 2               1        13.0   34.0     A    34
# 3               1        12.5   33.5     A    72

# %%
mean_temp=df_missing.Temp.mean()
df_missing.fillna({'Temp':mean_temp}, inplace=False)
# Out:
#     Name  Previous_Part  Participation1  Mini_Exam1     Mini_Exam2  \
# 0   Jake           32.0               1        19.5             20
# 1    Joe            NaN               1        20.0             16
# 2    Sol           31.0               1        22.0             13
# 3  Chris           30.0              -1        19.0  not available
#
#    Participation2  Mini_Exam3  Final Grade  Temp
# 0               1        10.0   33.0     A    -1
# 1               1        14.0   32.0     A    23
# 2               1        13.0   34.0     A    34
# 3               1        12.5   33.5     A    72

# %%
def Get_Gender_Bool(gender):
    if gender=='male':
      return 1
    else : 
      return 0
